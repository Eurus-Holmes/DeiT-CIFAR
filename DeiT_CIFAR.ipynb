# %%
# !git clone https://github.com/Eurus-Holmes/DeiT-CIFAR.git
# Out:
# Cloning into 'DeiT-CIFAR'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 25 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (25/25), done.

# %%
# %cd DeiT-CIFAR/
# Out:
# /content/DeiT-CIFAR

# %%
# !pip install timm==0.4.12
# Out:
# ...
#      |████████████████████████████████| 376 kB 4.8 MB/s
# ...

# %%
# !python main.py --finetune https://dl.fbaipublicfiles.com/deit/deit_tiny_patch16_224-a1311bcf.pth --data-set CIFAR-10 --model deit_tiny_patch16_224 --batch-size 128 --epochs 10 --output_dir tiny_CIFAR10
# Out:
# Not using distributed mode
# ...
